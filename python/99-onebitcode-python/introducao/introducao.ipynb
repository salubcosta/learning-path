# %% [markdown]
# # Introdução

# %%
num_1 = int(input("Informe um número 1: "))
num_2 = int(input("Informe um número 2: "))

greater_than = num_1 > num_2
less_than = num_1 < num_2
equal = num_1 == num_2
different = num_1 != num_2
bigger_equal = num_1 >= num_2
smaller_equal = num_1 <= num_2
print("greater_than",greater_than)
print("less_than",less_than)
print("equal",equal)
print("different",different)
print("bigger_equal",bigger_equal)
print("smaller_equal",smaller_equal)
# Out:
# greater_than True
# less_than False
# equal False
# different True
# bigger_equal True
# smaller_equal False

# %% [markdown]
# ### Desafio 1:
#
# 1 - Antecessor e Sucessor
#
# 2 - Calcular média de 4 notas

# %%
# 1 
number = int(input("Informe um número: "))
print(f"O antecessor de {number} é {number-1} e o sucessor é {number+1}")

# 2
n1 = int(input("Informe nota 1:"))
n2 = int(input("Informe nota 2:"))
n3 = int(input("Informe nota 3:"))
n4 = int(input("Informe nota 4:"))

print("A média é:", ((n1+n2+n3+n4)/4))
# Out:
# O antecessor de 10 é 9 e o sucessor é 11
# A média é: 8.0

# %% [markdown]
# ### Desafio 2:
#
# 1 - Substituindo caractere repetido:
# Escreva um programa Python para obter uma string de uma determinada string em que todas as ocorrências de seu primeiro caractere
# foram alteradas para $. exceto o próprio primeiro caractere.
# Exemplo: fifa 23 -> fi$a 23
#
# 2 - Troca de caracteres:
# Escreva um programa Python para obter uma única string de duas strings fornecidas separadas por um espaço e troque os dois primeiros
# caracteres de cada string.
# Exemplo: abc xyz -> xyz abc

# %%
# 1
var_1 = input("Informe um valor string: ")
new_str = ""
for i in var_1:
    if i == " ":
        new_str += " "
        continue
    if i not in new_str:
        new_str += i
    else:
        new_str += "$"
print(new_str)

# 2
caracteres = input("Informe duas strings: ")
caracteres = caracteres.split()

print(caracteres[::-1])
# Out:
# salu
# ['barbosa', 'salu']

# %%
names = {"Salumao", "Joelda", "Beatriz"}

print(names)
print([i for i in names][1])
# Out:
# {'Salumao', 'Beatriz', 'Joelda'}
# Beatriz
